# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('csv.csv')

# %%
display(df)
# Out:
#     PERIODO                                      SI  \
# 0       4.0       ADMINISTRACAO DE RECURSOS HUMANOS
# 1       NaN           ORGANIZACAO DE COMPUTADORES I
# 2       NaN                            ALGORITMOS I
# 3       NaN                  USUARIOS DA INFORMACAO
# 4       NaN                                    NADA
# 5       5.0               ADMINISTRACAO DA PRODUCAO
# 6       NaN              INTRODUÇÃO À CONTABILIDADE
# 7       NaN               LINGUAGENS DE PROGRAMACAO
# 8       NaN             NTERACAO HUMANO-COMPUTADOR
# 9       NaN  ORGANIZACAO E TRATAMENTO DA INFORMACAO
# 10      6.0                ADMINISTRACAO DE CUSTOS
# 11      NaN                   ENGENHARIA DE SOFTWAR
# 12      NaN                   SISTEMAS OPERACIONAIS
# 13      NaN                                    NADA
# 14      7.0                ADMINISTRACAO FINANCEIRA
# 15      NaN               ENGENHARIA DE SOFTWARE II
# 16      NaN                   REDES DE COMPUTADORES
# ...
